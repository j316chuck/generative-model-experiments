# %%
import warnings
warnings.filterwarnings("ignore")

import sys
import itertools
from keras.utils import plot_model
from keras.layers import Input, Dense, Reshape, Flatten
from keras import layers, initializers
from keras.models import Model, load_model
import keras.backend as K
import numpy as np
from seqtools import SequenceTools as ST
from gfp_gp import SequenceGP
from util import AA, AA_IDX
from util import build_vae
from sklearn.model_selection import train_test_split, ShuffleSplit
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
from gan import WGAN
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import scipy.stats
from scipy.stats import norm
from scipy.optimize import minimize
from keras.utils.generic_utils import get_custom_objects
from util import one_hot_encode_aa, partition_data, get_balaji_predictions, get_samples
from util import convert_idx_array_to_aas, build_pred_vae_model, get_experimental_X_y, count_substring_mismatch
from util import get_gfp_X_y_aa, load_gfp_data, one_hot_encode_aa, one_hot_encode, get_all_amino_acids, get_wild_type_amino_acid_sequence
from losses import neg_log_likelihood
import json
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7175b16ae72c> in <module>()
#      10 import keras.backend as K
#      11 import numpy as np
# ---> 12 from seqtools import SequenceTools as ST
#      13 from gfp_gp import SequenceGP
#      14 from util import AA, AA_IDX
#
# ModuleNotFoundError: No module named 'seqtools'

# %%
def build_model(M):
    x = Input(shape=(M, 20,))
    y = Flatten()(x)
    y = Dense(50, activation='elu')(y)
    y = Dense(2)(y)
    model = Model(inputs=x, outputs=y)
    return model

def evaluate_ground_truth(X_aa, ground_truth, save_file=None):
    y_gt = ground_truth.predict(X_aa, print_every=100000)[:, 0]
    if save_file is not None:
        np.save(save_file, y_gt)
        
def train_and_save_oracles(X_train, y_train, n=10, suffix='', batch_size=100):
    for i in range(n):
        model = build_model(X_train.shape[1])
        model.compile(optimizer='adam',
                      loss=neg_log_likelihood,
                      )
        early_stop = EarlyStopping(monitor='val_loss', 
                                   min_delta=0, 
                                   patience=5, 
                                   verbose=1)

        model.fit(X_train, y_train, 
                  epochs=100, 
                  batch_size=batch_size, 
                  validation_split=0.1, 
                  callbacks=[early_stop],
                  verbose=2)
        model.save("models/oracle_%i%s.h5" % (i, suffix))

# %%
def weighted_ml_opt(X_train, oracles, ground_truth, vae_0, weights_type='dbas',
        LD=20, iters=20, samples=500, homoscedastic=False, homo_y_var=0.1,
        quantile=0.95, verbose=False, alpha=1, train_gt_evals=None,
        cutoff=1e-6, it_epochs=10, enc1_units=50):
    
    assert weights_type in ['cbas', 'dbas','rwr', 'cem-pi', 'fbvae']
    L = X_train.shape[1]
    vae = build_vae(latent_dim=LD,
                    n_tokens=20, seq_length=L,
                    enc1_units=enc1_units)

    traj = np.zeros((iters, 7))
    oracle_samples = np.zeros((iters, samples))
    gt_samples = np.zeros((iters, samples))
    oracle_max_seq = None
    oracle_max = -np.inf
    gt_of_oracle_max = -np.inf
    y_star = - np.inf
    for t in range(iters):
        ### Take Samples ###
        zt = np.random.randn(samples, LD)
        if t > 0:
            Xt_p = vae.decoder_.predict(zt)
            Xt = get_samples(Xt_p)
        else:
            Xt = X_train
        
        ### Evaluate ground truth and oracle ###
        yt, yt_var = get_balaji_predictions(oracles, Xt)
        if homoscedastic:
            yt_var = np.ones_like(yt) * homo_y_var
        Xt_aa = np.argmax(Xt, axis=-1)
        if t == 0 and train_gt_evals is not None:
            yt_gt = train_gt_evals
        else:
            yt_gt = ground_truth.predict(Xt_aa, print_every=1000000)[:, 0]
        
        ### Calculate weights for different schemes ###
        if t > 0:
            if weights_type == 'cbas': 
                log_pxt = np.sum(np.log(Xt_p) * Xt, axis=(1, 2))
                X0_p = vae_0.decoder_.predict(zt)
                log_px0 = np.sum(np.log(X0_p)*Xt, axis=(1, 2))
                w1 = np.exp(log_px0-log_pxt)
                y_star_1 = np.percentile(yt, quantile*100)
                if y_star_1 > y_star:
                    y_star = y_star_1
                w2= scipy.stats.norm.sf(y_star, loc=yt, scale=np.sqrt(yt_var))
                weights = w1*w2 
            elif weights_type == 'cem-pi':
                pi = scipy.stats.norm.sf(max_train_gt, loc=yt, scale=np.sqrt(yt_var))
                pi_thresh = np.percentile(pi, quantile*100)
                weights = (pi > pi_thresh).astype(int)
            elif weights_type == 'dbas':
                y_star_1 = np.percentile(yt, quantile*100)
                if y_star_1 > y_star:
                    y_star = y_star_1
                weights = scipy.stats.norm.sf(y_star, loc=yt, scale=np.sqrt(yt_var))
            elif weights_type == 'rwr':
                weights = np.exp(alpha*yt)
                weights /= np.sum(weights)
#             elif weights_type == ''
        else:
            weights = np.ones(yt.shape[0])
            max_train_gt = np.max(yt_gt)
            
        yt_max_idx = np.argmax(yt)
        yt_max = yt[yt_max_idx]
        if yt_max > oracle_max:
            oracle_max = yt_max
            try:
                oracle_max_seq = convert_idx_array_to_aas(Xt_aa[yt_max_idx-1:yt_max_idx])[0]
            except IndexError:
                print(Xt_aa[yt_max_idx-1:yt_max_idx])
            gt_of_oracle_max = yt_gt[yt_max_idx]
        
        ### Record and print results ##
        if t == 0:
            rand_idx = np.random.randint(0, len(yt), samples)
            oracle_samples[t, :] = yt[rand_idx]
            gt_samples[t, :] = yt_gt[rand_idx]
        if t > 0:
            oracle_samples[t, :] = yt
            gt_samples[t, :] = yt_gt
        
        traj[t, 0] = np.max(yt_gt)
        traj[t, 1] = np.mean(yt_gt)
        traj[t, 2] = np.std(yt_gt)
        traj[t, 3] = np.max(yt)
        traj[t, 4] = np.mean(yt)
        traj[t, 5] = np.std(yt)
        traj[t, 6] = np.mean(yt_var)
        
        if verbose:
            print(weights_type.upper(), t, traj[t, 0], color.BOLD + str(traj[t, 1]) + color.END, 
                  traj[t, 2], traj[t, 3], color.BOLD + str(traj[t, 4]) + color.END, traj[t, 5], traj[t, 6])
        
        ### Train model ###
        if t == 0:
            vae.encoder_.set_weights(vae_0.encoder_.get_weights())
            vae.decoder_.set_weights(vae_0.decoder_.get_weights())
            vae.vae_.set_weights(vae_0.vae_.get_weights())
        else:
            cutoff_idx = np.where(weights < cutoff)
            Xt = np.delete(Xt, cutoff_idx, axis=0)
            yt = np.delete(yt, cutoff_idx, axis=0)
            weights = np.delete(weights, cutoff_idx, axis=0)
            vae.fit([Xt], [Xt, np.zeros(Xt.shape[0])],
                  epochs=it_epochs,
                  batch_size=10,
                  shuffle=False,
                  sample_weight=[weights, weights],
                  verbose=0)
            
    max_dict = {'oracle_max' : oracle_max, 
                'oracle_max_seq': oracle_max_seq, 
                'gt_of_oracle_max': gt_of_oracle_max}
    return traj, oracle_samples, gt_samples, max_dict

# %%
def fb_opt(X_train, oracles, ground_truth, vae_0, weights_type='fbvae',
        LD=20, iters=20, samples=500, 
        quantile=0.8, verbose=False, train_gt_evals=None,
        it_epochs=10, enc1_units=50):
    
    assert weights_type in ['fbvae']
    L = X_train.shape[1]
    vae = build_vae(latent_dim=LD,
                    n_tokens=20, seq_length=L,
                    enc1_units=enc1_units)

    traj = np.zeros((iters, 7))
    oracle_samples = np.zeros((iters, samples))
    gt_samples = np.zeros((iters, samples))
    oracle_max_seq = None
    oracle_max = -np.inf
    gt_of_oracle_max = -np.inf
    y_star = - np.inf
    for t in range(iters):
        ### Take Samples and evaluate ground truth and oracle ##
        zt = np.random.randn(samples, LD)
        if t > 0:
            Xt_sample_p = vae.decoder_.predict(zt)
            Xt_sample = get_samples(Xt_sample_p)
            yt_sample, _ = get_balaji_predictions(oracles, Xt_sample)
            Xt_aa_sample = np.argmax(Xt_sample, axis=-1)
            yt_gt_sample = ground_truth.predict(Xt_aa_sample, print_every=1000000)[:, 0]
        else:
            Xt = X_train
            yt, _ = get_balaji_predictions(oracles, Xt)
            Xt_aa = np.argmax(Xt, axis=-1)
            fb_thresh = np.percentile(yt, quantile*100)
            if train_gt_evals is not None:
                yt_gt = train_gt_evals
            else:
                yt_gt = ground_truth.predict(Xt_aa, print_every=1000000)[:, 0]
        
        ### Calculate threshold ###
        if t > 0:
            threshold_idx = np.where(yt_sample >= fb_thresh)[0]
            n_top = len(threshold_idx)
            sample_arrs = [Xt_sample, yt_sample, yt_gt_sample, Xt_aa_sample]
            full_arrs = [Xt, yt, yt_gt, Xt_aa]
            
            for l in range(len(full_arrs)):
                sample_arr = sample_arrs[l]
                full_arr = full_arrs[l]
                sample_top = sample_arr[threshold_idx]
                full_arr = np.concatenate([sample_top, full_arr])
                full_arr = np.delete(full_arr, range(full_arr.shape[0]-n_top, full_arr.shape[0]), axis=0)
                full_arrs[l] = full_arr
            Xt, yt, yt_gt, Xt_aa = full_arrs
        yt_max_idx = np.argmax(yt)
        yt_max = yt[yt_max_idx]
        if yt_max > oracle_max:
            oracle_max = yt_max
            try:
                oracle_max_seq = convert_idx_array_to_aas(Xt_aa[yt_max_idx-1:yt_max_idx])[0]
            except IndexError:
                print(Xt_aa[yt_max_idx-1:yt_max_idx])
            gt_of_oracle_max = yt_gt[yt_max_idx]
        
        ### Record and print results ##

        rand_idx = np.random.randint(0, len(yt), samples)
        oracle_samples[t, :] = yt[rand_idx]
        gt_samples[t, :] = yt_gt[rand_idx]

        traj[t, 0] = np.max(yt_gt)
        traj[t, 1] = np.mean(yt_gt)
        traj[t, 2] = np.std(yt_gt)
        traj[t, 3] = np.max(yt)
        traj[t, 4] = np.mean(yt)
        traj[t, 5] = np.std(yt)
        if t > 0:
            traj[t, 6] = n_top
        else:
            traj[t, 6] = 0
        
        if verbose:
            print(weights_type.upper(), t, traj[t, 0], color.BOLD + str(traj[t, 1]) + color.END, 
                  traj[t, 2], traj[t, 3], color.BOLD + str(traj[t, 4]) + color.END, traj[t, 5], traj[t, 6])
        
        ### Train model ###
        if t == 0:
            vae.encoder_.set_weights(vae_0.encoder_.get_weights())
            vae.decoder_.set_weights(vae_0.decoder_.get_weights())
            vae.vae_.set_weights(vae_0.vae_.get_weights())
        else:
        
            vae.fit([Xt], [Xt, np.zeros(Xt.shape[0])],
                  epochs=1,
                  batch_size=10,
                  shuffle=False,
                  verbose=0)
            
    max_dict = {'oracle_max' : oracle_max, 
                'oracle_max_seq': oracle_max_seq, 
                'gt_of_oracle_max': gt_of_oracle_max}
    return traj, oracle_samples, gt_samples, max_dict

# %%
def train_experimental_oracles():
    TRAIN_SIZE = 5000
    train_size_str = "%ik" % (TRAIN_SIZE/1000)
    i = 1
    num_models = [1, 5, 20]
    for i in range(len(num_models)):
        RANDOM_STATE = i+1
        nm = num_models[i]
        X_train, y_train, _  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE)
        suffix = '_%s_%i_%i' % (train_size_str, nm, RANDOM_STATE)
        train_and_save_oracles(X_train, y_train, batch_size=10, n=nm, suffix=suffix)

# %%
def train_experimental_vaes():
    TRAIN_SIZE = 5000
    train_size_str = "%ik" % (TRAIN_SIZE/1000)
    suffix = '_%s' % train_size_str
    for i in [0, 2]:
        RANDOM_STATE = i + 1
        X_train, _, _  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE)
        vae_0 = build_vae(latent_dim=20,
                  n_tokens=20, 
                  seq_length=X_train.shape[1],
                  enc1_units=50)
        vae_0.fit([X_train], [X_train, np.zeros(X_train.shape[0])],
                  epochs=100,
                  batch_size=10,
                  verbose=2)
        vae_0.encoder_.save_weights("models/vae_0_encoder_weights%s_%i.h5"% (suffix, RANDOM_STATE))
        vae_0.decoder_.save_weights("models/vae_0_decoder_weights%s_%i.h5"% (suffix, RANDOM_STATE))
        vae_0.vae_.save_weights("models/vae_0_vae_weights%s_%i.h5"% (suffix, RANDOM_STATE))

# %%
TRAIN_SIZE = 1000
RANDOM_STATE = 1
X_train, _, _, _  = load_gfp_data("./data/gfp_amino_acid_shuffle_")
X_train = one_hot_encode(X_train[0:TRAIN_SIZE], get_all_amino_acids())
X_train = X_train.reshape(X_train.shape[0], -1, len(get_all_amino_acids()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6c95782c5c2f> in <module>()
#       1 TRAIN_SIZE = 1000
#       2 RANDOM_STATE = 1
# ----> 3 X_train, _, _, _  = load_gfp_data("./data/gfp_amino_acid_shuffle_")
#       4 X_train = one_hot_encode(X_train[0:TRAIN_SIZE], get_all_amino_acids())
#       5 X_train = X_train.reshape(X_train.shape[0], -1, len(get_all_amino_acids()))
#
# NameError: name 'load_gfp_data' is not defined

# %%
from keras.callbacks import History 
history = History()
epochs = 100
vae_0 = build_vae(latent_dim=20,
                  n_tokens=21, 
                  seq_length=X_train.shape[1],
                  enc1_units=50)
vae_0.fit([X_train], [X_train, np.zeros(X_train.shape[0])],
          epochs=epochs,
          batch_size=10,
          verbose=True, callbacks=[history], 
         validation_split = 0.1)
vae_0.encoder_.save_weights("models/vae_0_encoder_weights_{0}.h5".format(epochs))
vae_0.decoder_.save_weights("models/vae_0_decoder_weights_{0}.h5".format(epochs))
vae_0.vae_.save_weights("models/vae_0_vae_weights_{0}.h5".format(epochs))
# Out:
# Train on 900 samples, validate on 100 samples
# Epoch 1/100
# 900/900 [==============================] - 5s 5ms/step - loss: 135.5982 - decoder_loss: 100.0888 - kl_reshape_loss: 35.5094 - val_loss: 44.3349 - val_decoder_loss: 32.2930 - val_kl_reshape_loss: 12.0419
# Epoch 2/100
# 900/900 [==============================] - 2s 2ms/step - loss: 41.8330 - decoder_loss: 31.8689 - kl_reshape_loss: 9.9641 - val_loss: 37.8486 - val_decoder_loss: 29.0495 - val_kl_reshape_loss: 8.7992
# Epoch 3/100
# 900/900 [==============================] - 2s 2ms/step - loss: 37.2469 - decoder_loss: 29.3561 - kl_reshape_loss: 7.8909 - val_loss: 36.0050 - val_decoder_loss: 29.0431 - val_kl_reshape_loss: 6.9619
# Epoch 4/100
# 900/900 [==============================] - 2s 2ms/step - loss: 34.3824 - decoder_loss: 27.8538 - kl_reshape_loss: 6.5286 - val_loss: 33.1739 - val_decoder_loss: 26.7518 - val_kl_reshape_loss: 6.4221
# Epoch 5/100
# 900/900 [==============================] - 2s 2ms/step - loss: 33.0320 - decoder_loss: 27.0815 - kl_reshape_loss: 5.9505 - val_loss: 32.2602 - val_decoder_loss: 27.0838 - val_kl_reshape_loss: 5.1764
# Epoch 6/100
# 900/900 [==============================] - 2s 2ms/step - loss: 32.2897 - decoder_loss: 26.7159 - kl_reshape_loss: 5.5738 - val_loss: 32.1457 - val_decoder_loss: 26.4481 - val_kl_reshape_loss: 5.6976
# Epoch 7/100
# 900/900 [==============================] - 2s 3ms/step - loss: 30.8921 - decoder_loss: 25.9429 - kl_reshape_loss: 4.9492 - val_loss: 30.3485 - val_decoder_loss: 25.5868 - val_kl_reshape_loss: 4.7617
# Epoch 8/100
# 900/900 [==============================] - 2s 2ms/step - loss: 30.5842 - decoder_loss: 25.7404 - kl_reshape_loss: 4.8438 - val_loss: 31.8506 - val_decoder_loss: 25.9738 - val_kl_reshape_loss: 5.8768
# Epoch 9/100
# 900/900 [==============================] - 2s 2ms/step - loss: 30.1539 - decoder_loss: 25.4258 - kl_reshape_loss: 4.7281 - val_loss: 30.1775 - val_decoder_loss: 26.3584 - val_kl_reshape_loss: 3.8191
# Epoch 10/100
# 900/900 [==============================] - 2s 2ms/step - loss: 29.3328 - decoder_loss: 25.3177 - kl_reshape_loss: 4.0151 - val_loss: 29.4346 - val_decoder_loss: 24.6813 - val_kl_reshape_loss: 4.7533
# Epoch 11/100
# 900/900 [==============================] - 2s 2ms/step - loss: 28.3023 - decoder_loss: 24.6156 - kl_reshape_loss: 3.6867 - val_loss: 28.7672 - val_decoder_loss: 25.8204 - val_kl_reshape_loss: 2.9469
# Epoch 12/100
# 900/900 [==============================] - 2s 2ms/step - loss: 28.2741 - decoder_loss: 24.7728 - kl_reshape_loss: 3.5013 - val_loss: 27.9805 - val_decoder_loss: 24.7897 - val_kl_reshape_loss: 3.1908
# Epoch 13/100
# 900/900 [==============================] - 2s 2ms/step - loss: 27.6015 - decoder_loss: 24.4967 - kl_reshape_loss: 3.1048 - val_loss: 27.4482 - val_decoder_loss: 24.4463 - val_kl_reshape_loss: 3.0019
# Epoch 14/100
# 900/900 [==============================] - 2s 2ms/step - loss: 26.7075 - decoder_loss: 24.2263 - kl_reshape_loss: 2.4811 - val_loss: 27.0216 - val_decoder_loss: 24.3949 - val_kl_reshape_loss: 2.6267
# Epoch 15/100
# 900/900 [==============================] - 2s 2ms/step - loss: 26.2528 - decoder_loss: 24.0223 - kl_reshape_loss: 2.2305 - val_loss: 26.5055 - val_decoder_loss: 24.3859 - val_kl_reshape_loss: 2.1195
# Epoch 16/100
# 900/900 [==============================] - 2s 2ms/step - loss: 25.9979 - decoder_loss: 23.9659 - kl_reshape_loss: 2.0321 - val_loss: 26.3097 - val_decoder_loss: 24.2806 - val_kl_reshape_loss: 2.0291
# Epoch 17/100
# 900/900 [==============================] - 2s 2ms/step - loss: 25.8454 - decoder_loss: 23.9705 - kl_reshape_loss: 1.8749 - val_loss: 26.3056 - val_decoder_loss: 24.5523 - val_kl_reshape_loss: 1.7533
# Epoch 18/100
# 900/900 [==============================] - 2s 2ms/step - loss: 25.3757 - decoder_loss: 23.6876 - kl_reshape_loss: 1.6881 - val_loss: 25.4935 - val_decoder_loss: 23.8976 - val_kl_reshape_loss: 1.5959
# Epoch 19/100
# 900/900 [==============================] - 2s 2ms/step - loss: 25.2270 - decoder_loss: 23.6963 - kl_reshape_loss: 1.5307 - val_loss: 25.9255 - val_decoder_loss: 24.2870 - val_kl_reshape_loss: 1.6385
# Epoch 20/100
# 900/900 [==============================] - 2s 2ms/step - loss: 25.0089 - decoder_loss: 23.5183 - kl_reshape_loss: 1.4906 - val_loss: 25.9433 - val_decoder_loss: 24.3985 - val_kl_reshape_loss: 1.5448
# Epoch 21/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.9818 - decoder_loss: 23.5701 - kl_reshape_loss: 1.4116 - val_loss: 25.4110 - val_decoder_loss: 24.1511 - val_kl_reshape_loss: 1.2600
# Epoch 22/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.7869 - decoder_loss: 23.5146 - kl_reshape_loss: 1.2723 - val_loss: 25.6397 - val_decoder_loss: 24.2267 - val_kl_reshape_loss: 1.4131
# Epoch 23/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.6994 - decoder_loss: 23.4194 - kl_reshape_loss: 1.2800 - val_loss: 25.2346 - val_decoder_loss: 24.0991 - val_kl_reshape_loss: 1.1356
# Epoch 24/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.7092 - decoder_loss: 23.4789 - kl_reshape_loss: 1.2303 - val_loss: 25.2007 - val_decoder_loss: 24.0664 - val_kl_reshape_loss: 1.1343
# Epoch 25/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.5017 - decoder_loss: 23.3231 - kl_reshape_loss: 1.1786 - val_loss: 24.9823 - val_decoder_loss: 23.9586 - val_kl_reshape_loss: 1.0237
# Epoch 26/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.4749 - decoder_loss: 23.3332 - kl_reshape_loss: 1.1417 - val_loss: 24.9972 - val_decoder_loss: 23.8010 - val_kl_reshape_loss: 1.1962
# Epoch 27/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.3457 - decoder_loss: 23.2804 - kl_reshape_loss: 1.0653 - val_loss: 24.8905 - val_decoder_loss: 23.8646 - val_kl_reshape_loss: 1.0258
# Epoch 28/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.1702 - decoder_loss: 23.1233 - kl_reshape_loss: 1.0470 - val_loss: 25.0215 - val_decoder_loss: 24.0865 - val_kl_reshape_loss: 0.9349
# Epoch 29/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.2272 - decoder_loss: 23.2657 - kl_reshape_loss: 0.9615 - val_loss: 24.8448 - val_decoder_loss: 23.9870 - val_kl_reshape_loss: 0.8578
# Epoch 30/100
# 900/900 [==============================] - 2s 2ms/step - loss: 24.0342 - decoder_loss: 23.1471 - kl_reshape_loss: 0.8871 - val_loss: 24.7055 - val_decoder_loss: 23.8412 - val_kl_reshape_loss: 0.8643
# Epoch 31/100
# 900/900 [==============================] - 2s 2ms/step - loss: 23.8726 - decoder_loss: 23.0353 - kl_reshape_loss: 0.8373 - val_loss: 24.7214 - val_decoder_loss: 24.1050 - val_kl_reshape_loss: 0.6164
# Epoch 32/100
# 900/900 [==============================] - 2s 2ms/step - loss: 23.8187 - decoder_loss: 23.0817 - kl_reshape_loss: 0.7370 - val_loss: 24.3490 - val_decoder_loss: 23.7175 - val_kl_reshape_loss: 0.6315
# Epoch 33/100
# 900/900 [==============================] - 2s 2ms/step - loss: 23.5840 - decoder_loss: 22.9127 - kl_reshape_loss: 0.6713 - val_loss: 24.5395 - val_decoder_loss: 23.8562 - val_kl_reshape_loss: 0.6833
# Epoch 34/100
# 900/900 [==============================] - 3s 3ms/step - loss: 23.5003 - decoder_loss: 22.9108 - kl_reshape_loss: 0.5895 - val_loss: 24.2610 - val_decoder_loss: 23.7775 - val_kl_reshape_loss: 0.4835
# Epoch 35/100
# 900/900 [==============================] - 2s 3ms/step - loss: 23.4632 - decoder_loss: 22.9001 - kl_reshape_loss: 0.5630 - val_loss: 24.0925 - val_decoder_loss: 23.7259 - val_kl_reshape_loss: 0.3667
# Epoch 36/100
# 900/900 [==============================] - 2s 2ms/step - loss: 23.3111 - decoder_loss: 22.8387 - kl_reshape_loss: 0.4724 - val_loss: 24.1872 - val_decoder_loss: 23.8214 - val_kl_reshape_loss: 0.3658
# Epoch 37/100
# 900/900 [==============================] - 3s 3ms/step - loss: 23.1166 - decoder_loss: 22.6553 - kl_reshape_loss: 0.4612 - val_loss: 23.9988 - val_decoder_loss: 23.7369 - val_kl_reshape_loss: 0.2619
# Epoch 38/100
# 900/900 [==============================] - 2s 2ms/step - loss: 23.0315 - decoder_loss: 22.5476 - kl_reshape_loss: 0.4839 - val_loss: 23.8540 - val_decoder_loss: 23.6209 - val_kl_reshape_loss: 0.2331
# Epoch 39/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.9248 - decoder_loss: 22.4031 - kl_reshape_loss: 0.5217 - val_loss: 23.8815 - val_decoder_loss: 23.6105 - val_kl_reshape_loss: 0.2711
# Epoch 40/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.9116 - decoder_loss: 22.3352 - kl_reshape_loss: 0.5764 - val_loss: 24.0727 - val_decoder_loss: 23.7732 - val_kl_reshape_loss: 0.2994
# Epoch 41/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.9197 - decoder_loss: 22.2740 - kl_reshape_loss: 0.6457 - val_loss: 24.0329 - val_decoder_loss: 23.7331 - val_kl_reshape_loss: 0.2998
# Epoch 42/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.8235 - decoder_loss: 22.1074 - kl_reshape_loss: 0.7161 - val_loss: 24.1077 - val_decoder_loss: 23.7213 - val_kl_reshape_loss: 0.3865
# Epoch 43/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.7560 - decoder_loss: 21.9597 - kl_reshape_loss: 0.7963 - val_loss: 24.1517 - val_decoder_loss: 23.7917 - val_kl_reshape_loss: 0.3600
# Epoch 44/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.7786 - decoder_loss: 21.8981 - kl_reshape_loss: 0.8805 - val_loss: 24.4277 - val_decoder_loss: 23.8646 - val_kl_reshape_loss: 0.5631
# Epoch 45/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.7766 - decoder_loss: 21.8148 - kl_reshape_loss: 0.9618 - val_loss: 24.3395 - val_decoder_loss: 23.8208 - val_kl_reshape_loss: 0.5188
# Epoch 46/100
# 900/900 [==============================] - 2s 3ms/step - loss: 22.6077 - decoder_loss: 21.5428 - kl_reshape_loss: 1.0649 - val_loss: 24.2669 - val_decoder_loss: 23.7121 - val_kl_reshape_loss: 0.5547
# Epoch 47/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.6603 - decoder_loss: 21.5274 - kl_reshape_loss: 1.1329 - val_loss: 24.2684 - val_decoder_loss: 23.7914 - val_kl_reshape_loss: 0.4770
# Epoch 48/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.5155 - decoder_loss: 21.3320 - kl_reshape_loss: 1.1834 - val_loss: 24.5347 - val_decoder_loss: 23.8776 - val_kl_reshape_loss: 0.6571
# Epoch 49/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.4499 - decoder_loss: 21.1622 - kl_reshape_loss: 1.2877 - val_loss: 24.4392 - val_decoder_loss: 23.7650 - val_kl_reshape_loss: 0.6742
# Epoch 50/100
# 900/900 [==============================] - 2s 3ms/step - loss: 22.4087 - decoder_loss: 21.0696 - kl_reshape_loss: 1.3391 - val_loss: 24.2229 - val_decoder_loss: 23.5640 - val_kl_reshape_loss: 0.6589
# Epoch 51/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.2649 - decoder_loss: 20.7944 - kl_reshape_loss: 1.4705 - val_loss: 24.3821 - val_decoder_loss: 23.7428 - val_kl_reshape_loss: 0.6394
# Epoch 52/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.2997 - decoder_loss: 20.7544 - kl_reshape_loss: 1.5453 - val_loss: 24.5899 - val_decoder_loss: 23.8613 - val_kl_reshape_loss: 0.7286
# Epoch 53/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.2549 - decoder_loss: 20.6189 - kl_reshape_loss: 1.6360 - val_loss: 24.5274 - val_decoder_loss: 23.7285 - val_kl_reshape_loss: 0.7989
# Epoch 54/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.1041 - decoder_loss: 20.3974 - kl_reshape_loss: 1.7068 - val_loss: 24.4505 - val_decoder_loss: 23.6832 - val_kl_reshape_loss: 0.7673
# Epoch 55/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.1181 - decoder_loss: 20.3107 - kl_reshape_loss: 1.8074 - val_loss: 24.7097 - val_decoder_loss: 23.7771 - val_kl_reshape_loss: 0.9326
# Epoch 56/100
# 900/900 [==============================] - 2s 2ms/step - loss: 22.0233 - decoder_loss: 20.1188 - kl_reshape_loss: 1.9046 - val_loss: 24.6462 - val_decoder_loss: 23.7912 - val_kl_reshape_loss: 0.8550
# Epoch 57/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.9334 - decoder_loss: 19.9639 - kl_reshape_loss: 1.9694 - val_loss: 24.9253 - val_decoder_loss: 24.0411 - val_kl_reshape_loss: 0.8842
# Epoch 58/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.9419 - decoder_loss: 19.8996 - kl_reshape_loss: 2.0423 - val_loss: 24.8990 - val_decoder_loss: 23.8853 - val_kl_reshape_loss: 1.0137
# Epoch 59/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.7141 - decoder_loss: 19.5607 - kl_reshape_loss: 2.1533 - val_loss: 24.5909 - val_decoder_loss: 23.5817 - val_kl_reshape_loss: 1.0092
# Epoch 60/100
# 900/900 [==============================] - 2s 3ms/step - loss: 21.7065 - decoder_loss: 19.4974 - kl_reshape_loss: 2.2091 - val_loss: 25.1564 - val_decoder_loss: 24.0445 - val_kl_reshape_loss: 1.1119
# Epoch 61/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.7373 - decoder_loss: 19.4019 - kl_reshape_loss: 2.3354 - val_loss: 24.6413 - val_decoder_loss: 23.5301 - val_kl_reshape_loss: 1.1111
# Epoch 62/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.5381 - decoder_loss: 19.1229 - kl_reshape_loss: 2.4153 - val_loss: 24.9914 - val_decoder_loss: 23.7725 - val_kl_reshape_loss: 1.2188
# Epoch 63/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.6077 - decoder_loss: 19.1208 - kl_reshape_loss: 2.4869 - val_loss: 25.4754 - val_decoder_loss: 24.2334 - val_kl_reshape_loss: 1.2420
# Epoch 64/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.4570 - decoder_loss: 18.8641 - kl_reshape_loss: 2.5929 - val_loss: 25.1326 - val_decoder_loss: 23.7548 - val_kl_reshape_loss: 1.3778
# Epoch 65/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.4692 - decoder_loss: 18.7924 - kl_reshape_loss: 2.6768 - val_loss: 24.9571 - val_decoder_loss: 23.5366 - val_kl_reshape_loss: 1.4205
# Epoch 66/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.4099 - decoder_loss: 18.6405 - kl_reshape_loss: 2.7694 - val_loss: 25.1701 - val_decoder_loss: 23.8840 - val_kl_reshape_loss: 1.2860
# Epoch 67/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.1359 - decoder_loss: 18.3678 - kl_reshape_loss: 2.7680 - val_loss: 25.1395 - val_decoder_loss: 23.6573 - val_kl_reshape_loss: 1.4822
# Epoch 68/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.2658 - decoder_loss: 18.3739 - kl_reshape_loss: 2.8919 - val_loss: 25.1779 - val_decoder_loss: 23.7859 - val_kl_reshape_loss: 1.3919
# Epoch 69/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.3677 - decoder_loss: 18.3046 - kl_reshape_loss: 3.0630 - val_loss: 24.8097 - val_decoder_loss: 23.3544 - val_kl_reshape_loss: 1.4553
# Epoch 70/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.0752 - decoder_loss: 18.0022 - kl_reshape_loss: 3.0730 - val_loss: 25.4454 - val_decoder_loss: 24.0310 - val_kl_reshape_loss: 1.4145
# Epoch 71/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.1811 - decoder_loss: 18.0105 - kl_reshape_loss: 3.1706 - val_loss: 25.2170 - val_decoder_loss: 23.6132 - val_kl_reshape_loss: 1.6039
# Epoch 72/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.1668 - decoder_loss: 17.9408 - kl_reshape_loss: 3.2259 - val_loss: 25.5051 - val_decoder_loss: 23.9331 - val_kl_reshape_loss: 1.5721
# Epoch 73/100
# 900/900 [==============================] - 2s 2ms/step - loss: 21.0322 - decoder_loss: 17.6991 - kl_reshape_loss: 3.3331 - val_loss: 25.9099 - val_decoder_loss: 24.2534 - val_kl_reshape_loss: 1.6565
# Epoch 74/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.9362 - decoder_loss: 17.5577 - kl_reshape_loss: 3.3785 - val_loss: 25.3775 - val_decoder_loss: 23.6876 - val_kl_reshape_loss: 1.6899
# Epoch 75/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.9676 - decoder_loss: 17.4377 - kl_reshape_loss: 3.5299 - val_loss: 26.2010 - val_decoder_loss: 24.2845 - val_kl_reshape_loss: 1.9166
# Epoch 76/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.8646 - decoder_loss: 17.3067 - kl_reshape_loss: 3.5579 - val_loss: 26.2747 - val_decoder_loss: 24.3950 - val_kl_reshape_loss: 1.8797
# Epoch 77/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.7246 - decoder_loss: 17.1456 - kl_reshape_loss: 3.5790 - val_loss: 25.6147 - val_decoder_loss: 23.8285 - val_kl_reshape_loss: 1.7862
# Epoch 78/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.6417 - decoder_loss: 16.9317 - kl_reshape_loss: 3.7100 - val_loss: 25.8094 - val_decoder_loss: 24.1809 - val_kl_reshape_loss: 1.6285
# Epoch 79/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.6665 - decoder_loss: 16.9230 - kl_reshape_loss: 3.7435 - val_loss: 26.0602 - val_decoder_loss: 24.1228 - val_kl_reshape_loss: 1.9374
# Epoch 80/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.6290 - decoder_loss: 16.7306 - kl_reshape_loss: 3.8984 - val_loss: 26.2234 - val_decoder_loss: 23.9036 - val_kl_reshape_loss: 2.3198
# Epoch 81/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.4738 - decoder_loss: 16.5196 - kl_reshape_loss: 3.9542 - val_loss: 26.4192 - val_decoder_loss: 24.3521 - val_kl_reshape_loss: 2.0672
# Epoch 82/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.3732 - decoder_loss: 16.2970 - kl_reshape_loss: 4.0763 - val_loss: 26.6175 - val_decoder_loss: 24.6624 - val_kl_reshape_loss: 1.9551
# Epoch 83/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.0414 - decoder_loss: 16.1693 - kl_reshape_loss: 3.8721 - val_loss: 26.3583 - val_decoder_loss: 24.2107 - val_kl_reshape_loss: 2.1476s: 20.4582 - decoder_loss: 16.39
# Epoch 84/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.1398 - decoder_loss: 16.0216 - kl_reshape_loss: 4.1182 - val_loss: 26.5152 - val_decoder_loss: 24.3423 - val_kl_reshape_loss: 2.1728
# Epoch 85/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.1975 - decoder_loss: 15.9269 - kl_reshape_loss: 4.2706 - val_loss: 26.9547 - val_decoder_loss: 24.4971 - val_kl_reshape_loss: 2.4576
# Epoch 86/100
# 900/900 [==============================] - 2s 3ms/step - loss: 20.1474 - decoder_loss: 15.8052 - kl_reshape_loss: 4.3422 - val_loss: 26.0263 - val_decoder_loss: 23.8188 - val_kl_reshape_loss: 2.2075
# Epoch 87/100
# 900/900 [==============================] - 2s 3ms/step - loss: 19.9363 - decoder_loss: 15.5549 - kl_reshape_loss: 4.3814 - val_loss: 26.6368 - val_decoder_loss: 24.1990 - val_kl_reshape_loss: 2.4378
# Epoch 88/100
# 900/900 [==============================] - 2s 2ms/step - loss: 20.0749 - decoder_loss: 15.6231 - kl_reshape_loss: 4.4517 - val_loss: 26.1408 - val_decoder_loss: 23.5619 - val_kl_reshape_loss: 2.5789
# Epoch 89/100
# 900/900 [==============================] - 2s 3ms/step - loss: 19.8413 - decoder_loss: 15.2606 - kl_reshape_loss: 4.5808 - val_loss: 26.8301 - val_decoder_loss: 24.5204 - val_kl_reshape_loss: 2.3097
# Epoch 90/100
# 900/900 [==============================] - 2s 2ms/step - loss: 19.8811 - decoder_loss: 15.2766 - kl_reshape_loss: 4.6045 - val_loss: 27.1932 - val_decoder_loss: 24.7087 - val_kl_reshape_loss: 2.4845
# Epoch 91/100
# 900/900 [==============================] - 2s 3ms/step - loss: 19.8780 - decoder_loss: 15.1488 - kl_reshape_loss: 4.7292 - val_loss: 26.6921 - val_decoder_loss: 24.0873 - val_kl_reshape_loss: 2.6048
# Epoch 92/100
# 900/900 [==============================] - 2s 2ms/step - loss: 19.8734 - decoder_loss: 15.1509 - kl_reshape_loss: 4.7225 - val_loss: 26.4114 - val_decoder_loss: 23.7550 - val_kl_reshape_loss: 2.6564
# Epoch 93/100
# 900/900 [==============================] - 2s 2ms/step - loss: 19.4865 - decoder_loss: 14.7720 - kl_reshape_loss: 4.7145 - val_loss: 27.0574 - val_decoder_loss: 24.4866 - val_kl_reshape_loss: 2.5708
# Epoch 94/100
# 900/900 [==============================] - 2s 3ms/step - loss: 19.6326 - decoder_loss: 14.7904 - kl_reshape_loss: 4.8422 - val_loss: 26.9188 - val_decoder_loss: 24.4305 - val_kl_reshape_loss: 2.4882
# Epoch 95/100
# 900/900 [==============================] - 3s 3ms/step - loss: 19.6686 - decoder_loss: 14.7221 - kl_reshape_loss: 4.9465 - val_loss: 27.2805 - val_decoder_loss: 24.3227 - val_kl_reshape_loss: 2.9578
# Epoch 96/100
# 900/900 [==============================] - 3s 3ms/step - loss: 19.4008 - decoder_loss: 14.4298 - kl_reshape_loss: 4.9710 - val_loss: 26.8643 - val_decoder_loss: 24.2457 - val_kl_reshape_loss: 2.6186
# Epoch 97/100
# 900/900 [==============================] - 2s 2ms/step - loss: 19.3527 - decoder_loss: 14.2946 - kl_reshape_loss: 5.0580 - val_loss: 26.8332 - val_decoder_loss: 24.1000 - val_kl_reshape_loss: 2.7332
# Epoch 98/100
# 900/900 [==============================] - 2s 3ms/step - loss: 19.4177 - decoder_loss: 14.2841 - kl_reshape_loss: 5.1336 - val_loss: 27.1859 - val_decoder_loss: 24.2429 - val_kl_reshape_loss: 2.9430
# Epoch 99/100
# 900/900 [==============================] - 2s 3ms/step - loss: 19.4906 - decoder_loss: 14.2853 - kl_reshape_loss: 5.2053 - val_loss: 27.4052 - val_decoder_loss: 24.4093 - val_kl_reshape_loss: 2.9959
# Epoch 100/100
# 900/900 [==============================] - 2s 2ms/step - loss: 19.3447 - decoder_loss: 14.1339 - kl_reshape_loss: 5.2108 - val_loss: 27.6220 - val_decoder_loss: 24.9251 - val_kl_reshape_loss: 2.6969

# %%
plt.figure(figsize = (8, 6))
for loss in history.history.keys():
    plt.plot(history.history[loss], label=loss)
plt.legend()
plt.title("training loss history")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.savefig("./logs/base_vae_{0}_epochs_training_history.png".format(epochs))

# %%
vae_1 = build_vae(latent_dim=20,
                  n_tokens=21, 
                  seq_length=X_train.shape[1],
                  enc1_units=50)
vae_1.encoder_.load_weights("models/vae_0_encoder_weights_{0}.h5".format(epochs))
vae_1.decoder_.load_weights("models/vae_0_decoder_weights_{0}.h5".format(epochs))
vae_1.vae_.load_weights("models/vae_0_vae_weights_{0}.h5".format(epochs))

output_mean_0, output_var_0 = vae_0.encoder_.predict([X_train])
output_mean_1, output_var_1 = vae_1.encoder_.predict([X_train])
np.testing.assert_array_equal(output_mean_0, output_mean_1)
np.testing.assert_array_equal(output_var_0, output_var_1)
z = np.random.sample((1000, 20))
recon_0 = vae_0.decoder_.predict(z)
recon_1 = vae_1.decoder_.predict(z)
np.testing.assert_array_equal(recon_0, recon_1)

# %%
vocabulary = get_all_amino_acids()
num_characters = len(vocabulary)
index_to_character = dict(zip(range(num_characters), vocabulary))
wild_type = get_wild_type_amino_acid_sequence()

# %%
num_samples = 1000
z = np.random.sample((num_samples, 20))
outputs = vae_1.decoder_.predict(z)
mismatches, all_strings = [], []
for i in range(outputs.shape[0]):
    string = []
    for j in range(outputs.shape[1]):
        k = np.random.choice(list(range(num_characters)), p = outputs[i, j])
        string.append(index_to_character[k])
    all_strings.append("".join(string))
    mismatches.append(count_substring_mismatch(wild_type, all_strings[-1]))
    if i % 100 == 0:
        print("finished {0}/{1} samples".format(i, num_samples))
# Out:
# finished 0/1000 samples
# finished 100/1000 samples
# finished 200/1000 samples
# finished 300/1000 samples
# finished 400/1000 samples
# finished 500/1000 samples
# finished 600/1000 samples
# finished 700/1000 samples
# finished 800/1000 samples
# finished 900/1000 samples

# %%
plt.figure(figsize = (8, 6))
plt.title("number of mismatches")
plt.hist(np.array(mismatches), bins=15)
plt.xlabel("mismatches")
plt.ylabel("counts")
plt.savefig("./logs/base_vae_mismatch_from_wild_type_epoch_{0}".format(epochs))

# %%
data_mismatches = []
for amino_acid_seq in load_gfp_data("./data/gfp_amino_acid_shuffle_")[0]:
    data_mismatches.append(count_substring_mismatch(amino_acid_seq, wild_type))
plt.title("number of mismatches")
plt.hist(data_mismatches, bins = 15)
plt.xlabel("mismatches")
plt.ylabel("counts")
plt.savefig("./logs/X_train_wild_type_mismatches.png")

# %%
def run_experimental_weighted_ml(it, repeats=3):
    
    assert it in [0, 1, 2]
    
    TRAIN_SIZE = 5000
    train_size_str = "%ik" % (TRAIN_SIZE/1000)
    num_models = [1, 5, 20][it]
    RANDOM_STATE = it + 1
    
    X_train, y_train, gt_train  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE)
    
    vae_suffix = '_%s_%i' % (train_size_str, RANDOM_STATE)
    oracle_suffix = '_%s_%i_%i' % (train_size_str, num_models, RANDOM_STATE)
    
    vae_0 = build_vae(latent_dim=20,
                  n_tokens=20, 
                  seq_length=X_train.shape[1],
                  enc1_units=50)

    vae_0.encoder_.load_weights("models/vae_0_encoder_weights%s.h5" % vae_suffix)
    vae_0.decoder_.load_weights("models/vae_0_decoder_weights%s.h5"% vae_suffix)
    vae_0.vae_.load_weights("models/vae_0_vae_weights%s.h5"% vae_suffix)
    
    ground_truth = SequenceGP(load=True, load_prefix="data/gfp_gp")
    
    loss = neg_log_likelihood
    get_custom_objects().update({"neg_log_likelihood": loss})
    oracles = [load_model("models/oracle_%i%s.h5" % (i, oracle_suffix)) for i in range(num_models)]
    
    test_kwargs = [
#                    {'weights_type':'cbas', 'quantile': 1},
#                    {'weights_type':'rwr', 'alpha': 20},
#                    {'weights_type':'dbas', 'quantile': 0.95},
#                    {'weights_type':'cem-pi', 'quantile': 0.8},
        {'weights_type': 'fbvae', 'quantile': 0.8}
    ]
    
    base_kwargs = {
        'homoscedastic': False,
        'homo_y_var': 0.01,
        'train_gt_evals':gt_train,
        'samples':100,
        'cutoff':1e-6,
        'it_epochs':10,
        'verbose':True,
        'LD': 20,
        'enc1_units':50,
        'iters':1000
    }
    
    if num_models==1:
        base_kwargs['homoscedastic'] = True
        base_kwargs['homo_y_var'] = np.mean((get_balaji_predictions(oracles, X_train)[0] - y_train)**2)
    
    for k in range(repeats):
        for j in range(len(test_kwargs)):
            test_name = test_kwargs[j]['weights_type']
            suffix = "_%s_%i_%i" % (train_size_str, RANDOM_STATE, k)
            if test_name == 'fbvae':
#                 suffix = suffix + "_%.2f" % test_kwargs[j]['quantile']
                if base_kwargs['iters'] == 1000:
                    suffix += '_long'
            
                print(suffix)
                kwargs = {}
                kwargs.update(test_kwargs[j])
                kwargs.update(base_kwargs)
                [kwargs.pop(k) for k in ['homoscedastic', 'homo_y_var', 'cutoff', 'it_epochs']]
                test_traj, test_oracle_samples, test_gt_samples, test_max = fb_opt(np.copy(X_train), oracles, ground_truth, vae_0, **kwargs)
            else:
                kwargs = {}
                kwargs.update(test_kwargs[j])
                kwargs.update(base_kwargs)
                test_traj, test_oracle_samples, test_gt_samples, test_max = weighted_ml_opt(np.copy(X_train), oracles, ground_truth, vae_0, **kwargs)
                
            np.save('results/%s_traj%s.npy' %(test_name, suffix), test_traj)
            np.save('results/%s_oracle_samples%s.npy' % (test_name, suffix), test_oracle_samples)
            np.save('results/%s_gt_samples%s.npy'%(test_name, suffix), test_gt_samples )

            with open('results/%s_max%s.json'% (test_name, suffix), 'w') as outfile:
                json.dump(test_max, outfile)

# %%
def test_cbas_q(qs = [0.5, 0.75, 0.95, 1]):
    it = 0
    
    TRAIN_SIZE = 5000
    train_size_str = "%ik" % (TRAIN_SIZE/1000)
    num_models = [1, 5, 20][it]
    RANDOM_STATE = it + 1
    
    X_train, y_train, gt_train  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE)
    
    vae_suffix = '_%s_%i' % (train_size_str, RANDOM_STATE)
    oracle_suffix = '_%s_%i_%i' % (train_size_str, num_models, RANDOM_STATE)
    
    vae_0 = build_vae(latent_dim=20,
                  n_tokens=20, 
                  seq_length=X_train.shape[1],
                  enc1_units=50)

    vae_0.encoder_.load_weights("models/vae_0_encoder_weights%s.h5" % vae_suffix)
    vae_0.decoder_.load_weights("models/vae_0_decoder_weights%s.h5"% vae_suffix)
    vae_0.vae_.load_weights("models/vae_0_vae_weights%s.h5"% vae_suffix)
    
    ground_truth = SequenceGP(load=True, load_prefix="data/gfp_gp")
    
    loss = neg_log_likelihood
    get_custom_objects().update({"neg_log_likelihood": loss})
    oracles = [load_model("models/oracle_%i%s.h5" % (i, oracle_suffix)) for i in range(num_models)]
    
    test_kwargs = [ {'weights_type':'cbas', 'quantile': q} for q in qs]
    
    base_kwargs = {
        'homoscedastic': False,
        'homo_y_var': 0.01,
        'train_gt_evals':gt_train,
        'samples':100,
        'cutoff':1e-6,
        'it_epochs':10,
        'verbose':True,
        'LD': 20,
        'enc1_units':50,
        'iters':100
    }
    
    if num_models==1:
        base_kwargs['homoscedastic'] = True
        base_kwargs['homo_y_var'] = np.mean((get_balaji_predictions(oracles, X_train)[0] - y_train)**2)
    
    for j in range(len(test_kwargs)):
        test_name = test_kwargs[j]['weights_type']
        qj = test_kwargs[j]['quantile']
        suffix = "_qtest_%s_%i_%.2f" % (train_size_str, RANDOM_STATE, qj)
        print(suffix)
        kwargs = {}
        kwargs.update(test_kwargs[j])
        kwargs.update(base_kwargs)
        test_traj, test_oracle_samples, test_gt_samples, test_max = weighted_ml_opt(np.copy(X_train), oracles, ground_truth, vae_0, **kwargs)
        
        np.save('results/%s_traj%s.npy' %(test_name, suffix), test_traj)
        np.save('results/%s_oracle_samples%s.npy' % (test_name, suffix), test_oracle_samples)
        np.save('results/%s_gt_samples%s.npy'%(test_name, suffix), test_gt_samples )

        with open('results/%s_max%s.json'% (test_name, suffix), 'w') as outfile:
            json.dump(test_max, outfile)

# %%
# %load_ext autoreload
# %autoreload 2
from util import count_substring_mismatch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-6fd43bd34799> in <module>()
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from util import count_substring_mismatch
#
# ImportError: cannot import name 'count_substring_mismatch'

# %%
# train_experimental_vaes()
# train_experimental_oracles()

# for i in range(1):
#     run_experimental_weighted_ml(i, repeats=1)

test_cbas_q(qs=[0.5, 0.75, 0.95, 1])

# %%
def test_density():
    TRAIN_SIZE = 5000
    train_size_str = "%ik" % (TRAIN_SIZE/1000)
    RANDOM_STATE = it + 1

    X_train, y_train, gt_train, X_test, y_test, gt_test  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE, return_test=True)

    vae_suffix = '_%s_%i' % (train_size_str, RANDOM_STATE)

    vae_0 = build_vae(latent_dim=20,
              n_tokens=20, 
              seq_length=X_train.shape[1],
              enc1_units=50)

    vae_0.encoder_.load_weights("models/vae_0_encoder_weights%s.h5" % vae_suffix)
    vae_0.decoder_.load_weights("models/vae_0_decoder_weights%s.h5"% vae_suffix)
    vae_0.vae_.load_weights("models/vae_0_vae_weights%s.h5"% vae_suffix)
    
    X_shuffle = np.zeros_like(X_train)
    for i in range
